# %% [markdown]
# # Anime User Based

# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %%
anime = pd.read_csv('../anime-recommendations-database/anime.csv')
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %% [markdown]
# anime_id = ID identifying an anime
# genre = list of genres for this anime
# rating = average rating out of 10 for this anime

# %%
animeRating = pd.read_csv('../anime-recommendations-database/rating.csv')
animeRating.tail()
# Out:
#          user_id  anime_id  rating
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9

# %% [markdown]
# anime_id = anime the user has rated
# rating = rating out of 10 (-1 if user watched but didn't assign a rating)

# %% [markdown]
# ### Cleaning Data for Missing Values

# %%
#Checking which values are null
print anime.isnull().sum()
print animeRating.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
anime['genre'] = anime['genre'].fillna('None')
anime['type'] = anime['type'].fillna('None')
anime['rating'] = anime['rating'].fillna('None')
anime.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
animeRating = animeRating[animeRating.rating > 0]
animeRating.rating.unique()
# Out:
# array([10,  8,  6,  9,  7,  3,  5,  4,  1,  2], dtype=int64)

# %%
fullMergedAnime = animeRating.merge(anime, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])
fullMergedAnime.head()
# Out:
#    user_id  anime_id  rating_user                    name  \
# 0        1      8074           10  Highschool of the Dead
# 1        3      8074            6  Highschool of the Dead
# 2        5      8074            2  Highschool of the Dead
# 3       12      8074            6  Highschool of the Dead
# 4       14      8074            6  Highschool of the Dead
#
#                                  genre type episodes rating  members
# 0  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 1  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 2  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 3  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 4  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892

# %% [markdown]
# ### Splitting and Normalizing Data

# %%
mergedSubAnime = fullMergedAnime[['user_id', 'anime_id', 'name', 'rating_user']]

#Limiting the dataframe
mergedSubAnime = mergedSubAnime[mergedSubAnime.user_id <= 6000]

# %%
trainData, testData = train_test_split(mergedSubAnime, test_size=0.2)

# %%
piv = trainData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(piv.shape)
# Out:
# (5614, 6809)

# %%
piv.head()
# Out:
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 2                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum ...  \
# user_id                                    ...
# 1                      NaN             NaN ...
# 2                      NaN             NaN ...
# 3                      NaN             NaN ...
# 5                      NaN             NaN ...
# 7                      NaN             NaN ...
#
# name     gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# user_id
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 7                                                    NaN
#
# name     iDOLM@STER Xenoglossia  iDOLM@STER Xenoglossia Specials  s.CRY.ed  \
# user_id
# 1                           NaN                              NaN       NaN
# 2                           NaN                              NaN       NaN
# 3                           NaN                              NaN       NaN
# 5                           NaN                              NaN       NaN
# 7                           NaN                              NaN       NaN
#
# name     xxxHOLiC  xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# user_id
# 1             NaN           NaN                                      NaN
# 2             NaN           NaN                                      NaN
# 3             NaN           NaN                                      NaN
# 5             2.0           NaN                                      NaN
# 7             NaN           NaN                                      NaN
#
# name     xxxHOLiC Rou  xxxHOLiC Shunmuki   ◯
# user_id
# 1                 NaN                NaN NaN
# 2                 NaN                NaN NaN
# 3                 NaN                NaN NaN
# 5                 NaN                NaN NaN
# 7                 NaN                NaN NaN
#
# [5 rows x 6809 columns]

# %%
piv_norm = piv.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)
piv_norm.fillna(0, inplace=True)

# %%
piv_norm = piv_norm.T

# %%
piv_norm = piv_norm.loc[:, (piv_norm != 0).any(axis=0)]

# %%
piv_norm.head()
# Out:
# user_id                                             3     5     7     8     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             11    12        14    \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0  0.000000
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0  0.000000
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0  0.169231
# .hack//G.U. Returner                                 0.0   0.0  0.000000
# .hack//G.U. Trilogy                                  0.0   0.0  0.000000
#
# user_id                                             16    17    18    ...   \
# name                                                                  ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0  ...
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0  ...
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0  ...
# .hack//G.U. Returner                                 0.0   0.0   0.0  ...
# .hack//G.U. Trilogy                                  0.0   0.0   0.0  ...
#
# user_id                                             5986  5989  5990  5991  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             5992  5993  5994  5997  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0   0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0   0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0   0.0   0.0
#
# user_id                                             5999  6000
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   0.0   0.0
# &quot;Bungaku Shoujo&quot; Memoire                   0.0   0.0
# &quot;Bungaku Shoujo&quot; Movie                     0.0   0.0
# .hack//G.U. Returner                                 0.0   0.0
# .hack//G.U. Trilogy                                  0.0   0.0
#
# [5 rows x 5120 columns]

# %%
piv_sparse = sp.sparse.csr_matrix(piv_norm.values)

# %% [markdown]
# ### User Cosine Similarity

# %%
userCosineSimilarity = cosine_similarity(piv_sparse.T)
print userCosineSimilarity
# Out:
# [[ 1.          0.04260516  0.15566908 ...  0.04234534  0.
#    0.01840256]
#  [ 0.04260516  1.          0.04122464 ...  0.050485   -0.0086376
#    0.01605437]
#  [ 0.15566908  0.04122464  1.         ...  0.04747978  0.
#   -0.01182892]
#  ...
#  [ 0.04234534  0.050485    0.04747978 ...  1.          0.04071469
#    0.0823297 ]
#  [ 0.         -0.0086376   0.         ...  0.04071469  1.
#    0.        ]
#  [ 0.01840256  0.01605437 -0.01182892 ...  0.0823297   0.
#    1.        ]]

# %%
userSimData = pd.DataFrame(userCosineSimilarity, index = piv_norm.columns, columns = piv_norm.columns)

# %%
userSimData.head()
# Out:
# user_id      3         5         7         8         11        12        14    \
# user_id
# 3        1.000000  0.042605  0.155669  0.010605  0.082607  0.065477  0.012600
# 5        0.042605  1.000000  0.041225 -0.011078  0.031792  0.061975  0.105060
# 7        0.155669  0.041225  1.000000 -0.013438 -0.036203  0.062923  0.063765
# 8        0.010605 -0.011078 -0.013438  1.000000  0.013833  0.007802 -0.085993
# 11       0.082607  0.031792 -0.036203  0.013833  1.000000  0.036085 -0.004367
#
# user_id      16        17        18      ...         5986      5989      5990  \
# user_id                                  ...
# 3        0.059192  0.132059  0.045978    ...     0.012936  0.032764  0.062925
# 5       -0.003933  0.094331 -0.008005    ...     0.002288  0.000000  0.000000
# 7        0.035836  0.099306  0.022571    ...     0.038438 -0.050015 -0.022988
# 8        0.000000  0.001276 -0.094697    ...     0.000000  0.000000  0.000000
# 11       0.042595  0.030922  0.017031    ...    -0.005035  0.015956  0.017943
#
# user_id      5991      5992      5993      5994      5997      5999      6000
# user_id
# 3        0.067224 -0.017127 -0.019331  0.044599  0.042345  0.000000  0.018403
# 5        0.012426  0.035405 -0.025907  0.087275  0.050485 -0.008638  0.016054
# 7        0.022932 -0.021682 -0.028583  0.052672  0.047480  0.000000 -0.011829
# 8        0.000000  0.000000 -0.050668 -0.007846  0.004765  0.000000  0.000000
# 11       0.027839  0.108587 -0.021089  0.037101  0.024229 -0.137683  0.005248
#
# [5 rows x 5120 columns]

# %%
userSimData[11].keys()
# Out:
# Int64Index([   3,    5,    7,    8,   11,   12,   14,   16,   17,   18,
#             ...
#             5986, 5989, 5990, 5991, 5992, 5993, 5994, 5997, 5999, 6000],
#            dtype='int64', name=u'user_id', length=5120)

# %%
def all_Similar_Users(currentUser):
    if currentUser not in piv_norm.columns:
        return("No data available for {}".format(currentUser))
    
    similarUsers = userSimData.sort_values(by=currentUser, ascending=False).index
    similarUsersResults = userSimData.sort_values(by=currentUser, ascending=False).loc[:,currentUser].tolist()
    similarUsersZipped = zip(similarUsers, similarUsersResults)
#     print similarUsersZipped
    
    return similarUsersZipped

# %%
# print all_Similar_Users(7)
# Out:
# [(7L, 1.000000000000003), (693L, 0.2136144591469744), (4762L, 0.1771748480680781), (2723L, 0.17482591151513238), (3038L, 0.16834741165157077), (2634L, 0.15848300601750306), (3L, 0.1556690844733206), (656L, 0.15018327083710561), (5127L, 0.1500995071783109), (559L, 0.1489879321817369), (4379L, 0.14889510999224212), (2740L, 0.14822274708672098), (2281L, 0.14780825460240596), (969L, 0.14725742591532992), (1106L, 0.14570332312651219), (3239L, 0.14566165356275698), (166L, 0.14436692341080898), (4820L, 0.1438631107853004), (837L, 0.13862626708852838), (725L, 0.13839925100256548), (345L, 0.13754124985474375), (2411L, 0.13707195069960
# %%
def avgRatingsUser(user):
    userRatings = piv.loc[user, :]
    avgUserRatingList = 0.0
    counter = 0
    for rating in userRatings:
        if not np.isnan(rating):
            avgUserRatingList += rating
            counter += 1
        else:
            continue
    return avgUserRatingList/counter

# %%
# Define for current existing user that has some data available

def ratingsUserAnime(currentUser, animeName, similarUsers):
    ratingWeight = 0.0
    similarityWeight = 0.0
    avgCurrentUserRating = avgRatingsUser(currentUser)
#     similarUsers = userSimData[currentUser]
    
    if currentUser in piv_norm.columns:
        for user, userSimilarity in similarUsers:
            #Average of the similar user ratings
            avgUserRating = avgRatingsUser(user)
            
            #Find the rated anime
            userAnimeRating = piv.loc[user, animeName]
#             print userAnimeRating
            if np.isnan(userAnimeRating):
                continue
            elif not np.isnan(userAnimeRating):
#                 print userAnimeRating
                ratingWeight += (userAnimeRating - avgUserRating)*userSimilarity
                similarityWeight += abs(userSimilarity)
    else:
        return ("No data available for: {}".format(currentUser))
    
    if similarityWeight > 0:
        return avgCurrentUserRating + (ratingWeight/similarityWeight)
    else:
        return avgCurrentUserRating

# %%
similarUsers = all_Similar_Users(7)
# print ratingsUserAnime(10, "Zombie-Loan", similarUsers
print ratingsUserAnime(11, "Zombie-Loan", similarUsers)
# Out:
# 6.618191314195057

# %%
def predictUserRatings(currentUser):
    ratingsNone = {}
    animeColumn = list(piv.columns.values)
    currentUserRatings = piv.loc[currentUser, :].tolist()
    currentUserAnime = dict(zip(animeColumn, currentUserRatings))
    similarUsers = all_Similar_Users(currentUser)
#     print len(currentUserAnime)
    
#     print len(currentUserAnime)
    counter = 0
    for animeName, animeRating in currentUserAnime.items():
        if np.isnan(animeRating):
            counter += 1
#             ratingsNone[animeName] = ratingsUserAnime(currentUser, animeName, similarUsers)
#             print ("AnimeName: {}, Rating: {}".format(animeName, ratingsNone[animeName]))
    
    return ratingsNone

# %%
predictUserRatings(7)
# Out:
# 6809
# {}

# %% [markdown]
# ### User Pearson Similarity

# %%
piv_user = piv_norm.values
userCovariance = np.cov(piv_user.T)

# %%
userPearsonSimilarity = np.corrcoef(userCovariance)
# print testing2

# %%
userPearsonSimData = pd.DataFrame(userPearsonSimilarity, index = piv_norm.columns, columns = piv_norm.columns)

# %%
userPearsonSimData.head()
# Out:
# user_id      3         5         7         8         10        11        12    \
# user_id
# 3        1.000000  0.390599  0.540247  0.131393  0.230468  0.338315  0.442852
# 5        0.390599  1.000000  0.456861  0.003083  0.264419  0.175298  0.321363
# 7        0.540247  0.456861  1.000000  0.045588  0.146607  0.105991  0.374586
# 8        0.131393  0.003083  0.045588  1.000000 -0.161154  0.059567 -0.006389
# 10       0.230468  0.264419  0.146607 -0.161154  1.000000  0.049037  0.224339
#
# user_id      14        16        17      ...         4990      4991      4992  \
# user_id                                  ...
# 3        0.349422  0.321334  0.624789    ...     0.116088  0.260055  0.225033
# 5        0.551465  0.165403  0.601768    ...     0.158756  0.292935  0.235149
# 7        0.543455  0.315055  0.661314    ...     0.160566  0.263536  0.259735
# 8       -0.029386  0.026510  0.016668    ...    -0.044372 -0.007285  0.001524
# 10       0.223979  0.081027  0.313504    ...     0.068301  0.191987  0.059808
#
# user_id      4993      4995      4996      4997      4998      4999      5000
# user_id
# 3        0.341106 -0.137320  0.393180  0.087866  0.346094  0.247075  0.571032
# 5        0.498507  0.027153  0.121315  0.183013  0.366469  0.259727  0.615792
# 7        0.366285 -0.049507  0.292652 -0.016443  0.459601  0.437305  0.638354
# 8       -0.020292  0.002354  0.010841 -0.022189  0.034068 -0.010836  0.096772
# 10       0.359261  0.037801  0.113908  0.107205  0.159429  0.140987  0.232634
#
# [5 rows x 4319 columns]

# %%
def top_Similar_Pearson_Users(currentUser):
    if currentUser not in piv_norm.columns:
        return("No data available for {}".format(currentUser))
    
    similarUsers = userPearsonSimData.sort_values(by=currentUser, ascending=False).index[1:20]
    similarUsersResults = userPearsonSimData.sort_values(by=currentUser, ascending=False).loc[:,currentUser].tolist()[1:20]
    similarUsersZipped = zip(similarUsers, similarUsersResults)
#     print similarUsersZipped
    
    return similarUsersZipped

# %%
similarPearsonUsers = top_Similar_Pearson_Users(7)
print ratingsUserAnime(7, "Zombie-Loan", similarPearsonUsers)
# Out:
# 6.399927865841151

# %%
def predictPearsonUserRatings(currentUser):
    ratingsNone = {}
    animeColumn = list(piv.columns.values)
    currentUserRatings = piv.loc[currentUser, :].tolist()
    currentUserAnime = dict(zip(animeColumn, currentUserRatings))
    similarUsers = top_Similar_Pearson_Users(currentUser)
#     print len(currentUserAnime)
    
    for animeName, animeRating in currentUserAnime.items():
        if np.isnan(animeRating):
            ratingsNone[animeName] = ratingsUserAnime(currentUser, animeName, similarUsers)
            print ("User: {}, Rating: {}".format(user, ratingsNone[user]))
    
    return ratingsNone

# %% [markdown]
# ### Item Cosine Similarity

# %%
itemCosineSimilarity = cosine_similarity(piv_sparse)

# %%
itemSimData = pd.DataFrame(itemCosineSimilarity, index = piv_norm.index, columns = piv_norm.index)

# %%
itemSimData.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.172085
# &quot;Bungaku Shoujo&quot; Movie                                                             0.186285
# .hack//G.U. Returner                                                                         0.020928
# .hack//G.U. Trilogy                                                                          0.061367
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.172085
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.388434
# .hack//G.U. Returner                                                         -0.020467
# .hack//G.U. Trilogy                                                           0.037005
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.186285
# &quot;Bungaku Shoujo&quot; Memoire                                          0.388434
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                       -0.048346
# .hack//G.U. Trilogy                                                         0.044058
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...              0.020928
# &quot;Bungaku Shoujo&quot; Memoire                             -0.020467
# &quot;Bungaku Shoujo&quot; Movie                               -0.048346
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.559906
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.061367
# &quot;Bungaku Shoujo&quot; Memoire                             0.037005
# &quot;Bungaku Shoujo&quot; Movie                               0.044058
# .hack//G.U. Returner                                           0.559906
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.032293
# &quot;Bungaku Shoujo&quot; Memoire                                         -0.059632
# &quot;Bungaku Shoujo&quot; Movie                                           -0.027781
# .hack//G.U. Returner                                                       -0.149000
# .hack//G.U. Trilogy                                                        -0.153814
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...     0.004453
# &quot;Bungaku Shoujo&quot; Memoire                    -0.007363
# &quot;Bungaku Shoujo&quot; Movie                      -0.023449
# .hack//G.U. Returner                                   0.371347
# .hack//G.U. Trilogy                                    0.194511
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.043450
# &quot;Bungaku Shoujo&quot; Memoire                          -0.052221
# &quot;Bungaku Shoujo&quot; Movie                            -0.107170
# .hack//G.U. Returner                                         0.633474
# .hack//G.U. Trilogy                                          0.290773
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.017462
# &quot;Bungaku Shoujo&quot; Memoire                          -0.033056
# &quot;Bungaku Shoujo&quot; Movie                            -0.048258
# .hack//G.U. Returner                                         0.236892
# .hack//G.U. Trilogy                                          0.062776
#
# name                                                .hack//Quantum ...   \
# name                                                               ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.017125 ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.036570 ...
# &quot;Bungaku Shoujo&quot; Movie                          0.030136 ...
# .hack//G.U. Returner                                      0.199659 ...
# .hack//G.U. Trilogy                                       0.073942 ...
#
# name                                                gdgd Fairies 2  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.0
# &quot;Bungaku Shoujo&quot; Memoire                             0.0
# &quot;Bungaku Shoujo&quot; Movie                               0.0
# .hack//G.U. Returner                                           0.0
# .hack//G.U. Trilogy                                            0.0
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...               -0.005201
# &quot;Bungaku Shoujo&quot; Memoire                                0.004336
# &quot;Bungaku Shoujo&quot; Movie                                  0.002020
# .hack//G.U. Returner                                             -0.002475
# .hack//G.U. Trilogy                                              -0.001661
#
# name                                                iDOLM@STER Xenoglossia Specials  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         0.023101
# &quot;Bungaku Shoujo&quot; Memoire                                        -0.042659
# &quot;Bungaku Shoujo&quot; Movie                                          -0.019874
# .hack//G.U. Returner                                                       0.026172
# .hack//G.U. Trilogy                                                        0.017569
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.000000  0.075029
# &quot;Bungaku Shoujo&quot; Memoire                 -0.048821 -0.041747
# &quot;Bungaku Shoujo&quot; Movie                   -0.007470 -0.037358
# .hack//G.U. Returner                                0.000000 -0.052349
# .hack//G.U. Trilogy                                -0.017556 -0.027834
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.106081
# &quot;Bungaku Shoujo&quot; Memoire                     -0.050302
# &quot;Bungaku Shoujo&quot; Movie                       -0.038744
# .hack//G.U. Returner                                   -0.068782
# .hack//G.U. Trilogy                                    -0.009529
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.133147
# &quot;Bungaku Shoujo&quot; Memoire                                                -0.045607
# &quot;Bungaku Shoujo&quot; Movie                                                  -0.018042
# .hack//G.U. Returner                                                              -0.076498
# .hack//G.U. Trilogy                                                                0.008717
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.151144
# &quot;Bungaku Shoujo&quot; Memoire                     -0.016375
# &quot;Bungaku Shoujo&quot; Movie                        0.028878
# .hack//G.U. Returner                                   -0.104512
# .hack//G.U. Trilogy                                     0.005253
#
# name                                                xxxHOLiC Shunmuki    ◯
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.079971  0.0
# &quot;Bungaku Shoujo&quot; Memoire                          -0.091434  0.0
# &quot;Bungaku Shoujo&quot; Movie                             0.000960  0.0
# .hack//G.U. Returner                                        -0.141105  0.0
# .hack//G.U. Trilogy                                         -0.049467  0.0
#
# [5 rows x 6612 columns]

# %%
def top_Similar_Animes(anime):
    similarAnime = itemSimData.sort_values(by=anime, ascending=False).index[1:20]
    similarAnimeResults = itemSimData.sort_values(by=anime, ascending=False).loc[:,anime].tolist()[1:20]
    similarAnimeZipped = zip(similarAnime, similarAnimeResults)
#     print similarUsersZipped
    
    return similarAnimeZipped

# %%
def avgRatingItem(item):
    itemRatings = piv.loc[:, item]
    avgItemRatingList = []
    for rating in itemRatings:
        if not np.isnan(rating):
            avgItemRatingList.append(rating)
        else:
            continue
    return sum(avgItemRatingList)/len(avgItemRatingList)

# %%
def ratingsItemAnime(currentUser, animeName, similarItems):
    ratingWeight = []
    similarityWeight = []
    avgCurrentItemRating = avgRatingItem(animeName)
    
    if currentUser in piv_norm.columns:
        for item, itemSimilarity in similarItems:
            #Average of the similar item ratings
            avgItemRating = avgRatingItem(item)
            
            #Find the rated anime
            itemAnimeRating = piv.loc[currentUser, item]
            if np.isnan(itemAnimeRating):
                continue
            elif not np.isnan(itemAnimeRating):
                ratingWeight.append((itemAnimeRating - avgItemRating)*itemSimilarity)
                similarityWeight.append(abs(itemSimilarity))
    else:
        return ("No data available for: {}".format(currentUser))
    
    if sum(similarityWeight) > 0:
        return avgCurrentItemRating + (sum(ratingWeight)/sum(similarityWeight))
    else:
        return avgCurrentItemRating

# %%
similarAnimes = top_Similar_Animes("Zombie-Loan")
print ratingsItemAnime(7, "Zombie-Loan", similarAnimes)
# Out:
# 6.392857142857143

# %%
def predictItemRatings(currentItem):
    ratingsNone = {}
    animeRow = list(piv.index.values)
    currentItemRatings = piv.loc[:, currentItem].tolist()  
    currentUserAnime = dict(zip(animeRow, currentItemRatings))
    similarAnimes = top_Similar_Animes(currentItem)
#     print len(currentUserAnime)
#     similarUsers = top_Similar_Users(currentUser)
#     print currentUserAnime
    
    for user, animeRating in currentUserAnime.items():
        if np.isnan(animeRating):
#  1057: 7.192857142857143,
#  1058: 7.192857142857143,
#  1059: 7.192857142857143,
#  1060: 7.192857142857143,
#  1061: 7.192857142857143,
#  1062: 7.192857142857143,
#  1063: 7.192857142857143,
#  1064: 7.192857142857143,
#  1065: 7.192857142857143,
#  1066: 7.192857142857143,
#  1067: 7.192857142857143,
#  1068: 'No data available for: 1068',
#  1069: 7.192857142857143,
#  1070: 7.192857142857143,
#  1072: 7.192857142857143,
#  1073: 7.192857142857143,
#  1074: 7.192857142857143,
#  1075: 7.192857142857143,
#  1076: 7.192857142857143,
#  1077: 7.192857142857143,
#  1078: 7.192857142857143,
#  1079: 7.192857142857143,
#  1080: 7.192857142857143,
#  1081: 7.192857142857143,
#  1082: 7.192857142857143,
#  1083: 7.192857142857143,
#  1084: 7.192857142857143,
#  1085: 'No data available for: 1085',
#  1086: 'No data available for: 1086',
#  1087: 7.192857142857143,
#  1088: 7.192857142857143,
#  1089: 7.192857142857143,
#  1090: 7.192857142857143,
#  1091: 7.192857142857143,
#  1092: 7.192857142857143,
#  1093: 7.192857142857143,
#  1095: 7.192857142857143,
#  ...}

# %% [markdown]
# ### Item Pearson Similarity

# %%
piv_item = piv_norm.values
itemCovariance = np.cov(piv_item)

# %%
itemPearsonSimilarity = np.corrcoef(itemCovariance)

# %%
itemPearsonSimData = pd.DataFrame(itemPearsonSimilarity, index = piv_norm.index, columns = piv_norm.index)

# %%
itemPearsonSimData.head()

# %%
def top_Pearson_Similar_Animes(anime):
    similarAnime = itemPearsonSimData.sort_values(by=anime, ascending=False).index[1:20]
    similarAnimeResults = itemPearsonSimData.sort_values(by=anime, ascending=False).loc[:,anime].tolist()[1:20]
    similarAnimeZipped = zip(similarAnime, similarAnimeResults)
#     print similarUsersZipped
    
    return similarAnimeZipped

# %%
def predictPearsonItemRatings(currentItem):
    ratingsNone = {}
    animeRow = list(piv.index.values)
    currentItemRatings = piv.loc[:, currentItem].tolist()  
    currentUserAnime = dict(zip(animeRow, currentItemRatings))
    similarAnimes = top_Pearson_Similar_Animes(currentItem)
#     print len(currentUserAnime)
#     similarUsers = top_Similar_Users(currentUser)
#     print currentUserAnime
    
    for user, animeRating in currentUserAnime.items():
        if np.isnan(animeRating):
            ratingsNone[user] = ratingsItemAnime(user, currentItem, similarAnimes)
#             print ("User: {}, Rating: {}".format(user, ratingsNone[user]))
    return ratingsNone

# %%
predictPearsonItemRatings("Zombie-Loan")

# %% [markdown]
# ### Results

# %%
def get_mean_absolute_error():
    mean_absolute_error = 0.0
    n = 0.0
    test_users_rating_map = generate_ratings_users_map(test_users, test_ratings)
    test_5000 = test_users_rating_map.keys()[0:5000]
    for user_id in test_5000:
        user_ratings = test_users_rating_map[user_id]
        for rating in user_ratings:
            movie_id = rating['movie']
            actual_rating = float(rating['rating'])
            predicted_rating = predict_rating(user_id, movie_id)
            mean_absolute_error += abs(actual_rating - predicted_rating)
            n += 1
    return mean_absolute_error / n
mean_absolute_error = get_mean_absolute_error()

# %%
print mean_absolute_error
