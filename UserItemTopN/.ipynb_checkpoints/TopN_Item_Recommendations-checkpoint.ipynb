# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %%
anime = pd.read_csv('../anime-recommendations-database/anime.csv')
animeRating = pd.read_csv('../anime-recommendations-database/rating.csv')

# %% [markdown]
# ### Cleaning Data for Missing Values

# %%
#Checking which values are null
print anime.isnull().sum()
print animeRating.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
anime['genre'] = anime['genre'].fillna('None')
anime['type'] = anime['type'].fillna('None')
anime['rating'] = anime['rating'].fillna('None')
anime.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
animeRating = animeRating[animeRating.rating > 0]
animeRating.rating.unique()
# Out:
# array([10,  8,  6,  9,  7,  3,  5,  4,  1,  2], dtype=int64)

# %%
fullMergedAnime = animeRating.merge(anime, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])
fullMergedAnime.head()
# Out:
#    user_id  anime_id  rating_user                    name  \
# 0        1      8074           10  Highschool of the Dead
# 1        3      8074            6  Highschool of the Dead
# 2        5      8074            2  Highschool of the Dead
# 3       12      8074            6  Highschool of the Dead
# 4       14      8074            6  Highschool of the Dead
#
#                                  genre type episodes rating  members
# 0  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 1  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 2  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 3  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 4  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892

# %% [markdown]
# ### Splitting and Normalizing Data

# %%
trainData, testData = train_test_split(fullMergedAnime, test_size=0.2)

# %%
subTrainData = trainData[['user_id', 'anime_id', 'name', 'rating_user']]
#Limiting the dataframe
subTrainData = subTrainData[subTrainData.user_id <= 6000]

# %%
pivTrain = subTrainData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(pivTrain.shape)
pivTrain.head()
# Out:
# (5599, 6807)
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 2                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum ...  \
# user_id                                    ...
# 1                      NaN             NaN ...
# 2                      NaN             NaN ...
# 3                      NaN             NaN ...
# 5                      NaN             NaN ...
# 7                      NaN             NaN ...
#
# name     gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# user_id
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 7                                                    NaN
#
# name     iDOLM@STER Xenoglossia  iDOLM@STER Xenoglossia Specials  s.CRY.ed  \
# user_id
# 1                           NaN                              NaN       NaN
# 2                           NaN                              NaN       NaN
# 3                           NaN                              NaN       NaN
# 5                           NaN                              NaN       NaN
# 7                           NaN                              NaN       NaN
#
# name     xxxHOLiC  xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# user_id
# 1             NaN           NaN                                      NaN
# 2             NaN           NaN                                      NaN
# 3             NaN           NaN                                      NaN
# 5             2.0           NaN                                      NaN
# 7             NaN           NaN                                      NaN
#
# name     xxxHOLiC Rou  xxxHOLiC Shunmuki   ◯
# user_id
# 1                 NaN                NaN NaN
# 2                 NaN                NaN NaN
# 3                 NaN                NaN NaN
# 5                 NaN                NaN NaN
# 7                 NaN                NaN NaN
#
# [5 rows x 6807 columns]

# %%
subTestData = testData[['user_id', 'anime_id', 'name', 'rating_user']]
#Limiting the dataframe
subTestData = subTestData[subTestData.user_id <= 6000]

# %%
pivTest = subTestData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(pivTest.shape)
pivTest.head()
# Out:
# (5099, 5136)
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
# 8                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
# 8                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
# 8                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum        ...          \
# user_id                                           ...
# 1                      NaN             NaN        ...
# 3                      NaN             NaN        ...
# 5                      NaN             NaN        ...
# 7                      NaN             NaN        ...
# 8                      NaN             NaN        ...
#
# name     ef: A Tale of Memories. - Recollections  fake!fake!  gdgd Fairies  \
# user_id
# 1                                            NaN         NaN           NaN
# 3                                            NaN         NaN           NaN
# 5                                            NaN         NaN           NaN
# 7                                            NaN         NaN           NaN
# 8                                            NaN         NaN           NaN
#
# name     gdgd Fairies 2  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# user_id
# 1                   NaN       NaN       NaN           NaN
# 3                   NaN       NaN       NaN           NaN
# 5                   NaN       NaN       NaN           NaN
# 7                   NaN       NaN       NaN           NaN
# 8                   NaN       NaN       NaN           NaN
#
# name     xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 1                                            NaN           NaN
# 3                                            NaN           NaN
# 5                                            NaN           NaN
# 7                                            NaN           NaN
# 8                                            NaN           NaN
#
# name     xxxHOLiC Shunmuki
# user_id
# 1                      NaN
# 3                      NaN
# 5                      NaN
# 7                      NaN
# 8                      NaN
#
# [5 rows x 5136 columns]

# %%
def create_Normalized_Matrix(piv):
    piv = piv.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)
    piv.fillna(0, inplace=True)
    piv = piv.T
    piv = piv.loc[:, (piv != 0).any(axis=0)]
    return piv

# %%
pivTrainNorm = create_Normalized_Matrix(pivTrain)
print (pivTrainNorm.shape)
# Out:
# (6807, 5118)

# %%
pivTestNorm = create_Normalized_Matrix(pivTest)
print (pivTestNorm.shape)
# Out:
# (5136, 4386)

# %% [markdown]
# ### Create Sparse Matrices

# %%
def create_Sparse_Matrix(userAnimeMatrix):
    return sp.sparse.csr_matrix(userAnimeMatrix.values)

# %%
pivTrainSparse = create_Sparse_Matrix(pivTrainNorm)

# %% [markdown]
# ### Item-Item Cosine Similarity

# %%
def item_Cosine_Similarity(itemMatrix):
    return cosine_similarity(itemMatrix)

def item_Similarity_DataFrame(itemSim, pivNorm):
    return pd.DataFrame(itemSim, index = pivNorm.index, columns = pivNorm.index)

# %%
itemCosineSim = item_Cosine_Similarity(pivTrainSparse)
trainItemSimData = item_Similarity_DataFrame(itemCosineSim, pivTrainNorm)
trainItemSimData.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.027610
# &quot;Bungaku Shoujo&quot; Movie                                                             0.045682
# .hack//G.U. Returner                                                                         0.010205
# .hack//G.U. Trilogy                                                                          0.048056
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.027610
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.269141
# .hack//G.U. Returner                                                         -0.156174
# .hack//G.U. Trilogy                                                           0.030399
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.045682
# &quot;Bungaku Shoujo&quot; Memoire                                          0.269141
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                       -0.080683
# .hack//G.U. Trilogy                                                         0.040150
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...              0.010205
# &quot;Bungaku Shoujo&quot; Memoire                             -0.156174
# &quot;Bungaku Shoujo&quot; Movie                               -0.080683
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.161346
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.048056
# &quot;Bungaku Shoujo&quot; Memoire                             0.030399
# &quot;Bungaku Shoujo&quot; Movie                               0.040150
# .hack//G.U. Returner                                           0.161346
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         -0.001039
# &quot;Bungaku Shoujo&quot; Memoire                                         -0.325070
# &quot;Bungaku Shoujo&quot; Movie                                           -0.178834
# .hack//G.U. Returner                                                        0.173640
# .hack//G.U. Trilogy                                                         0.035187
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...     0.021875
# &quot;Bungaku Shoujo&quot; Memoire                    -0.128735
# &quot;Bungaku Shoujo&quot; Movie                      -0.082209
# .hack//G.U. Returner                                   0.319100
# .hack//G.U. Trilogy                                   -0.020581
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.000406
# &quot;Bungaku Shoujo&quot; Memoire                           0.001133
# &quot;Bungaku Shoujo&quot; Movie                            -0.014281
# .hack//G.U. Returner                                         0.333592
# .hack//G.U. Trilogy                                          0.032108
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.015956
# &quot;Bungaku Shoujo&quot; Memoire                          -0.099676
# &quot;Bungaku Shoujo&quot; Movie                             0.032634
# .hack//G.U. Returner                                         0.258068
# .hack//G.U. Trilogy                                         -0.017730
#
# name                                                .hack//Quantum ...   \
# name                                                               ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.013029 ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.027864 ...
# &quot;Bungaku Shoujo&quot; Movie                          0.053365 ...
# .hack//G.U. Returner                                      0.173327 ...
# .hack//G.U. Trilogy                                       0.040866 ...
#
# name                                                gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                              0.0
# &quot;Bungaku Shoujo&quot; Memoire                                                              0.0
# &quot;Bungaku Shoujo&quot; Movie                                                                0.0
# .hack//G.U. Returner                                                                            0.0
# .hack//G.U. Trilogy                                                                             0.0
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...               -0.002596
# &quot;Bungaku Shoujo&quot; Memoire                                0.003272
# &quot;Bungaku Shoujo&quot; Movie                                  0.001730
# .hack//G.U. Returner                                             -0.001821
# .hack//G.U. Trilogy                                              -0.002785
#
# name                                                iDOLM@STER Xenoglossia Specials  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         0.000000
# &quot;Bungaku Shoujo&quot; Memoire                                        -0.024601
# &quot;Bungaku Shoujo&quot; Movie                                          -0.013004
# .hack//G.U. Returner                                                       0.015107
# .hack//G.U. Trilogy                                                        0.011607
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.000000  0.055154
# &quot;Bungaku Shoujo&quot; Memoire                 -0.032063 -0.054735
# &quot;Bungaku Shoujo&quot; Movie                   -0.010064 -0.036254
# .hack//G.U. Returner                                0.003143  0.006192
# .hack//G.U. Trilogy                                 0.033962  0.009857
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.036195
# &quot;Bungaku Shoujo&quot; Memoire                     -0.021143
# &quot;Bungaku Shoujo&quot; Movie                       -0.040821
# .hack//G.U. Returner                                   -0.038969
# .hack//G.U. Trilogy                                    -0.018522
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.115179
# &quot;Bungaku Shoujo&quot; Memoire                                                -0.050443
# &quot;Bungaku Shoujo&quot; Movie                                                  -0.064025
# .hack//G.U. Returner                                                              -0.025732
# .hack//G.U. Trilogy                                                                0.028853
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.117881
# &quot;Bungaku Shoujo&quot; Memoire                     -0.019577
# &quot;Bungaku Shoujo&quot; Movie                       -0.051122
# .hack//G.U. Returner                                   -0.077994
# .hack//G.U. Trilogy                                     0.036363
#
# name                                                xxxHOLiC Shunmuki    ◯
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.090457  0.0
# &quot;Bungaku Shoujo&quot; Memoire                          -0.062251  0.0
# &quot;Bungaku Shoujo&quot; Movie                            -0.026064  0.0
# .hack//G.U. Returner                                        -0.010530  0.0
# .hack//G.U. Trilogy                                         -0.007420  0.0
#
# [5 rows x 6807 columns]

# %% [markdown]
# ### Item-Item Cosine Implementation

# %%
def items_Avg_Rating_Matrix(itemMatrix):
    avgItemsRating = {}
    for itemID in itemMatrix:
        ratingsSum = 0.0
        counter = 0
        for rating in itemMatrix[itemID]:
            if not np.isnan(rating):
                ratingsSum += rating
                counter += 1
            else:
                continue
        avgItemsRating[itemID] = ratingsSum / counter
    return avgItemsRating

def item_Avg_Rating(itemID):
    itemRatings = pivTrain.loc[itemID, :]
    avgItemRatingList = 0.0
    counter = 0
    for rating in itemRatings:
        if not np.isnan(rating):
            avgItemRatingList += rating
            counter += 1
        else:
            continue
    return avgItemRatingList/counter

# %%
avgItemRatings = items_Avg_Rating_Matrix(pivTrain)
# print avgItemRatings
# avgItemRating = item_Avg_Rating(3)
# print avgItemRating

# %%
def rating_Item_Prediction(userID, animeName):
    if userID in pivTrainNorm.columns:
        allItemSimilarity = trainItemSimData.sort_values(by=animeName, ascending=False).loc[:,animeName]
        itemAvg = avgItemRatings[animeName]
        ratingWeight = 0.0
        similarityWeight = 0.0
        topNUsers = 0
        
        for itemX in allItemSimilarity.index:
            if animeName == itemX:
                continue
            
            itemXRating = pivTrain.loc[userID, itemX]
            if itemXRating < 0.01:
                continue
    
            if topNUsers < 50:
                itemXAvg = avgItemRatings[itemX]
                itemXSimilarity = allItemSimilarity.loc[itemX]
                if np.isnan(itemXRating):
                    continue
                elif not np.isnan(itemXRating):
                    ratingWeight += (itemXRating - itemXAvg)*itemXSimilarity
                    similarityWeight += abs(itemXSimilarity)
                    topNUsers += 1

    else:
        return ("No data available for UserID: {}".format(userID))
    
    return itemAvg + (ratingWeight / similarityWeight)

# %%
itemCosinePrediction = rating_Item_Prediction(3, "Zombie-Loan")
print itemCosinePrediction
# Out:
# 6.594450106949019

# %% [markdown]
# ### Evaluation of Item-Item Cosine Similarity using MAE and RMSE

# %%
# Mean Absolute Error
def calc_Mean_Absolute_Error():
    meanAbsErrorList = 0.0
    count = 0
    for anime in pivTest.columns:
        if anime in pivTestNorm.index:
            itemInfo = pivTest.loc[:, anime]
            for userID in itemInfo.index:
                trueRating = itemInfo[userID]
                if np.isnan(trueRating):
                    continue
                predictedRating = rating_Item_Prediction(userID, anime)
                meanAbsErrorList += abs(predictedRating - trueRating)
                count += 1
    return meanAbsErrorList/count


# Root Mean Squared Error
import math
def calc_Root_Mean_Square_Error():
    rootMSEList = 0.0
    count = 0
    for anime in pivTest.columns:
        if anime in pivTestNorm.index:
            itemInfo = pivTest.loc[:, anime]
            for userID in itemInfo.index:
                trueRating = itemInfo[userID]
                if np.isnan(trueRating):
                    continue
                predictedRating = rating_Item_Prediction(userID, anime)
                rootMSEList += (predictedRating - trueRating)**2
                count += 1
    return math.sqrt(rootMSEList / count)

# %%
itemCosineMAE = calc_Mean_Absolute_Error()
print itemCosineMAE
# Out:
# 1.0006945928569715

# %%
itemCosineRMSE = calc_Root_Mean_Square_Error()
print itemCosineRMSE
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-7dc502574d47> in <module>()
# ----> 1 itemCosineRMSE = calc_Root_Mean_Square_Error()
#       2 print itemCosineRMSE
#
# <ipython-input-77-0d45130a2df8> in calc_Root_Mean_Square_Error()
#      28                 if np.isnan(trueRating):
#      29                     continue
# ---> 30                 predictedRating = rating_Item_Prediction(userID, anime)
#      31                 rootMSEList += (predictedRating - trueRating)**2
#      32                 count += 1
#
# <ipython-input-59-193e4026e60e> in rating_Item_Prediction(userID, animeName)
#      11                 continue
#      12
# ---> 13             itemXRating = pivTrain.loc[userID, itemX]
#      14             if itemXRating < 0.01:
#      15                 continue
#
# C:\Users\Hernandez-TAMU\Anaconda2\envs\cs670\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1361                         for x in key)
#    1362             try:
# -> 1363                 if self._is_scalar_access(key):
#    1364                     return self._getitem_scalar(key)
#    1365             except (KeyError, IndexError):
#
# C:\Users\Hernandez-TAMU\Anaconda2\envs\cs670\lib\site-packages\pandas\core\indexing.pyc in _is_scalar_access(self, key)
#    1532
#    1533             ax = self.obj.axes[i]
# -> 1534             if isinstance(ax, MultiIndex):
#    1535                 return False
#    1536
#
# KeyboardInterrupt:

# %% [markdown]
# ### Item-Item Pearson Similarity

# %%
def pearson_Covariance(userMatrix):
    return np.cov(userMatrix.T)

def pearson_Similarity(userCovariance):
    return np.corrcoef(userCovariance)

# %%
userPearsonCovariance = pearson_Covariance(pivTrainNorm.values)

# %%
userPearsonSim = pearson_Similarity(userPearsonCovariance)

# %%
trainUserPSimData = user_Similarity_DataFrame(userPearsonSim, pivTrainNorm)
trainUserPSimData.head()
