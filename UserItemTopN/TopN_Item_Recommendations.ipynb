# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %%
anime = pd.read_csv('../anime-recommendations-database/anime.csv')
animeRating = pd.read_csv('../anime-recommendations-database/rating.csv')

# %% [markdown]
# ### Cleaning Data for Missing Values

# %%
#Checking which values are null
print anime.isnull().sum()
print animeRating.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
anime['genre'] = anime['genre'].fillna('None')
anime['type'] = anime['type'].fillna('None')
anime['rating'] = anime['rating'].fillna('None')
anime.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
animeRating = animeRating[animeRating.rating > 0]
animeRating.rating.unique()
# Out:
# array([10,  8,  6,  9,  7,  3,  5,  4,  1,  2], dtype=int64)

# %%
fullMergedAnime = animeRating.merge(anime, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])
fullMergedAnime.head()
# Out:
#    user_id  anime_id  rating_user                    name  \
# 0        1      8074           10  Highschool of the Dead
# 1        3      8074            6  Highschool of the Dead
# 2        5      8074            2  Highschool of the Dead
# 3       12      8074            6  Highschool of the Dead
# 4       14      8074            6  Highschool of the Dead
#
#                                  genre type episodes rating  members
# 0  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 1  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 2  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 3  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 4  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892

# %% [markdown]
# ### Splitting and Normalizing Data

# %%
trainData, testData = train_test_split(fullMergedAnime, test_size=0.2)

# %%
subTrainData = trainData[['user_id', 'anime_id', 'name', 'rating_user']]
#Limiting the dataframe
subTrainData = subTrainData[subTrainData.user_id <= 6000]

# %%
pivTrain = subTrainData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(pivTrain.shape)
pivTrain.head()
# Out:
# (5606, 6780)
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 2                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum ...  \
# user_id                                    ...
# 1                      NaN             NaN ...
# 2                      NaN             NaN ...
# 3                      NaN             NaN ...
# 5                      NaN             NaN ...
# 7                      NaN             NaN ...
#
# name     gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# user_id
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 7                                                    NaN
#
# name     iDOLM@STER Xenoglossia  iDOLM@STER Xenoglossia Specials  s.CRY.ed  \
# user_id
# 1                           NaN                              NaN       NaN
# 2                           NaN                              NaN       NaN
# 3                           NaN                              NaN       NaN
# 5                           NaN                              NaN       NaN
# 7                           NaN                              NaN       NaN
#
# name     xxxHOLiC  xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# user_id
# 1             NaN           NaN                                      NaN
# 2             NaN           NaN                                      NaN
# 3             NaN           NaN                                      NaN
# 5             2.0           NaN                                      NaN
# 7             NaN           NaN                                      NaN
#
# name     xxxHOLiC Rou  xxxHOLiC Shunmuki   ◯
# user_id
# 1                 NaN                NaN NaN
# 2                 NaN                NaN NaN
# 3                 NaN                NaN NaN
# 5                 NaN                NaN NaN
# 7                 NaN                NaN NaN
#
# [5 rows x 6780 columns]

# %%
subTestData = testData[['user_id', 'anime_id', 'name', 'rating_user']]
#Limiting the dataframe
subTestData = subTestData[subTestData.user_id <= 6000]

# %%
pivTest = subTestData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(pivTest.shape)
pivTest.head()
# Out:
# (5069, 5136)
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
# 8                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
# 8                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
# 8                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum        ...          \
# user_id                                           ...
# 1                      NaN             NaN        ...
# 3                      NaN             NaN        ...
# 5                      NaN             NaN        ...
# 7                      NaN             NaN        ...
# 8                      NaN             NaN        ...
#
# name     ef: A Tale of Memories. - Prologue  \
# user_id
# 1                                       NaN
# 3                                       NaN
# 5                                       NaN
# 7                                       NaN
# 8                                       NaN
#
# name     ef: A Tale of Memories. - Recollections  gdgd Fairies 2  \
# user_id
# 1                                            NaN             NaN
# 3                                            NaN             NaN
# 5                                            NaN             NaN
# 7                                            NaN             NaN
# 8                                            NaN             NaN
#
# name     iDOLM@STER Xenoglossia  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# user_id
# 1                           NaN       NaN       NaN           NaN
# 3                           NaN       NaN       NaN           NaN
# 5                           NaN       NaN       NaN           NaN
# 7                           NaN       NaN       NaN           NaN
# 8                           NaN       NaN       NaN           NaN
#
# name     xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 1                                            NaN           NaN
# 3                                            NaN           NaN
# 5                                            NaN           NaN
# 7                                            NaN           NaN
# 8                                            NaN           NaN
#
# name     xxxHOLiC Shunmuki
# user_id
# 1                      NaN
# 3                      NaN
# 5                      NaN
# 7                      NaN
# 8                      NaN
#
# [5 rows x 5136 columns]

# %%
def create_Normalized_Matrix(piv):
    piv = piv.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)
    piv.fillna(0, inplace=True)
    piv = piv.T
    piv = piv.loc[:, (piv != 0).any(axis=0)]
    return piv

# %%
pivTrainNorm = create_Normalized_Matrix(pivTrain)
print (pivTrainNorm.shape)
# Out:
# (6780, 5120)

# %%
pivTestNorm = create_Normalized_Matrix(pivTest)
print (pivTestNorm.shape)
# Out:
# (5136, 4395)

# %% [markdown]
# ### Create Sparse Matrices

# %%
def create_Sparse_Matrix(userAnimeMatrix):
    return sp.sparse.csr_matrix(userAnimeMatrix.values)

# %%
pivTrainSparse = create_Sparse_Matrix(pivTrainNorm)

# %% [markdown]
# ### Item-Item Cosine Similarity

# %%
def item_Cosine_Similarity(itemMatrix):
    return cosine_similarity(itemMatrix)

def item_Similarity_DataFrame(itemSim, pivNorm):
    return pd.DataFrame(itemSim, index = pivNorm.index, columns = pivNorm.index)

# %%
itemCosineSim = item_Cosine_Similarity(pivTrainSparse)
trainItemSimData = item_Similarity_DataFrame(itemCosineSim, pivTrainNorm)
trainItemSimData.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.161675
# &quot;Bungaku Shoujo&quot; Movie                                                             0.215310
# .hack//G.U. Returner                                                                        -0.001366
# .hack//G.U. Trilogy                                                                          0.038945
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.161675
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.263576
# .hack//G.U. Returner                                                         -0.017160
# .hack//G.U. Trilogy                                                           0.028893
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.215310
# &quot;Bungaku Shoujo&quot; Memoire                                          0.263576
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                        0.002162
# .hack//G.U. Trilogy                                                         0.041009
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             -0.001366
# &quot;Bungaku Shoujo&quot; Memoire                             -0.017160
# &quot;Bungaku Shoujo&quot; Movie                                0.002162
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.179289
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.038945
# &quot;Bungaku Shoujo&quot; Memoire                             0.028893
# &quot;Bungaku Shoujo&quot; Movie                               0.041009
# .hack//G.U. Returner                                           0.179289
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         -0.131438
# &quot;Bungaku Shoujo&quot; Memoire                                         -0.249021
# &quot;Bungaku Shoujo&quot; Movie                                           -0.151323
# .hack//G.U. Returner                                                        0.092026
# .hack//G.U. Trilogy                                                         0.061632
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    -0.044528
# &quot;Bungaku Shoujo&quot; Memoire                    -0.105970
# &quot;Bungaku Shoujo&quot; Movie                      -0.089945
# .hack//G.U. Returner                                   0.086559
# .hack//G.U. Trilogy                                    0.087967
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.000123
# &quot;Bungaku Shoujo&quot; Memoire                          -0.011278
# &quot;Bungaku Shoujo&quot; Movie                            -0.010636
# .hack//G.U. Returner                                         0.418163
# .hack//G.U. Trilogy                                          0.104654
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.062613
# &quot;Bungaku Shoujo&quot; Memoire                          -0.095333
# &quot;Bungaku Shoujo&quot; Movie                            -0.085264
# .hack//G.U. Returner                                         0.243162
# .hack//G.U. Trilogy                                          0.004676
#
# name                                                .hack//Quantum ...   \
# name                                                               ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.004168 ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.010084 ...
# &quot;Bungaku Shoujo&quot; Movie                          0.025262 ...
# .hack//G.U. Returner                                      0.088149 ...
# .hack//G.U. Trilogy                                       0.004214 ...
#
# name                                                gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                              0.0
# &quot;Bungaku Shoujo&quot; Memoire                                                              0.0
# &quot;Bungaku Shoujo&quot; Movie                                                                0.0
# .hack//G.U. Returner                                                                            0.0
# .hack//G.U. Trilogy                                                                             0.0
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                0.000000
# &quot;Bungaku Shoujo&quot; Memoire                                0.000345
# &quot;Bungaku Shoujo&quot; Movie                                  0.000000
# .hack//G.U. Returner                                              0.000000
# .hack//G.U. Trilogy                                               0.000000
#
# name                                                iDOLM@STER Xenoglossia Specials  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         0.013971
# &quot;Bungaku Shoujo&quot; Memoire                                         0.000000
# &quot;Bungaku Shoujo&quot; Movie                                          -0.013879
# .hack//G.U. Returner                                                       0.000000
# .hack//G.U. Trilogy                                                        0.010202
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.000000  0.057788
# &quot;Bungaku Shoujo&quot; Memoire                 -0.052951 -0.027997
# &quot;Bungaku Shoujo&quot; Movie                    0.000000 -0.008144
# .hack//G.U. Returner                                0.000000 -0.078149
# .hack//G.U. Trilogy                                 0.013413 -0.011520
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.064614
# &quot;Bungaku Shoujo&quot; Memoire                      0.037681
# &quot;Bungaku Shoujo&quot; Movie                        0.021686
# .hack//G.U. Returner                                   -0.066525
# .hack//G.U. Trilogy                                     0.006183
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.114775
# &quot;Bungaku Shoujo&quot; Memoire                                                -0.030469
# &quot;Bungaku Shoujo&quot; Movie                                                   0.041121
# .hack//G.U. Returner                                                               0.028175
# .hack//G.U. Trilogy                                                                0.044456
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.100432
# &quot;Bungaku Shoujo&quot; Memoire                     -0.066979
# &quot;Bungaku Shoujo&quot; Movie                        0.035961
# .hack//G.U. Returner                                   -0.087675
# .hack//G.U. Trilogy                                     0.053164
#
# name                                                xxxHOLiC Shunmuki    ◯
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.108838  0.0
# &quot;Bungaku Shoujo&quot; Memoire                          -0.078972  0.0
# &quot;Bungaku Shoujo&quot; Movie                             0.025136  0.0
# .hack//G.U. Returner                                        -0.154139  0.0
# .hack//G.U. Trilogy                                          0.024037  0.0
#
# [5 rows x 6780 columns]

# %% [markdown]
# ### Item-Item Cosine Implementation

# %%
def items_Avg_Rating_Matrix(itemMatrix):
    avgItemsRating = {}
    for itemID in itemMatrix:
        ratingsSum = 0.0
        counter = 0
        for rating in itemMatrix[itemID]:
            if not np.isnan(rating):
                ratingsSum += rating
                counter += 1
            else:
                continue
        avgItemsRating[itemID] = ratingsSum / counter
    return avgItemsRating

def item_Avg_Rating(itemID):
    itemRatings = pivTrain.loc[itemID, :]
    avgItemRatingList = 0.0
    counter = 0
    for rating in itemRatings:
        if not np.isnan(rating):
            avgItemRatingList += rating
            counter += 1
        else:
            continue
    return avgItemRatingList/counter

# %%
avgItemRatings = items_Avg_Rating_Matrix(pivTrain)
# print avgItemRatings
# avgItemRating = item_Avg_Rating(3)
# print avgItemRating

# %%
def rating_Item_Cosine_Prediction(userID, animeName):
    if userID in pivTrainNorm.columns:
        allItemSimilarity = trainItemSimData.sort_values(by=animeName, ascending=False).loc[:,animeName]
        itemAvg = avgItemRatings[animeName]
        ratingWeight = 0.0
        similarityWeight = 0.0
        topNUsers = 0
        
        for itemX in allItemSimilarity.index:
            if animeName == itemX:
                continue
            
            itemXRating = pivTrain.loc[userID, itemX]
            if itemXRating < 0.01:
                continue
    
            if topNUsers < 50:
                itemXAvg = avgItemRatings[itemX]
                itemXSimilarity = allItemSimilarity.loc[itemX]
                if np.isnan(itemXRating):
                    continue
                elif not np.isnan(itemXRating):
                    ratingWeight += (itemXRating - itemXAvg)*itemXSimilarity
                    similarityWeight += abs(itemXSimilarity)
                    topNUsers += 1

    else:
        return ("No data available for UserID: {}".format(userID))
    
    return itemAvg + (ratingWeight / similarityWeight)

# %%
itemCosinePrediction = rating_Item_Cosine_Prediction(3, "Zombie-Loan")
print itemCosinePrediction
# Out:
# 6.693252992288715

# %% [markdown]
# ### Evaluation of Item-Item Cosine Similarity using MAE and RMSE

# %%
# Mean Absolute Error and Root Mean Squared Error
import math
def calc_Cosine_Error():
    meanAbsErrorList = 0.0
    rootMSEList = 0.0
    count = 0
    for anime in pivTest.columns:
        if anime in pivTestNorm.index:
            itemInfo = pivTest.loc[:, anime]
            for userID in itemInfo.index:
                trueRating = itemInfo[userID]
                if np.isnan(trueRating):
                    continue
                predictedRating = rating_Item_Cosine_Prediction(userID, anime)
                meanAbsErrorList += abs(predictedRating - trueRating)
                rootMSEList += (predictedRating - trueRating)**2
                count += 1
    return meanAbsErrorList/count, math.sqrt(rootMSEList/count)

# %%
cosineMAE, cosineRMSE = calc_Cosine_Error()
print "MAE: {}".format(cosineMAE)
print "RMSE: {}".format(cosineRMSE)
# Out:
# 1.0006945928569715

# %% [markdown]
# ### Item-Item Pearson Similarity

# %%
def pearson_Covariance(itemMatrix):
    return np.cov(itemMatrix)

def pearson_Similarity(itemCovariance):
    return np.corrcoef(itemCovariance)

# %%
itemPearsonCovariance = pearson_Covariance(pivTrainNorm.values)

# %%
itemPearsonSim = pearson_Similarity(itemPearsonCovariance)
# Out:
# C:\Users\Hernandez-TAMU\Anaconda2\envs\cs670\lib\site-packages\numpy\lib\function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Hernandez-TAMU\Anaconda2\envs\cs670\lib\site-packages\numpy\lib\function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
trainItemPSimData = item_Similarity_DataFrame(itemPearsonSim, pivTrainNorm)
trainItemPSimData.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.098315
# &quot;Bungaku Shoujo&quot; Movie                                                             0.299798
# .hack//G.U. Returner                                                                        -0.050094
# .hack//G.U. Trilogy                                                                          0.074303
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.098315
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.321392
# .hack//G.U. Returner                                                         -0.025891
# .hack//G.U. Trilogy                                                           0.071005
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.299798
# &quot;Bungaku Shoujo&quot; Memoire                                          0.321392
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                       -0.176810
# .hack//G.U. Trilogy                                                         0.035272
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             -0.050094
# &quot;Bungaku Shoujo&quot; Memoire                             -0.025891
# &quot;Bungaku Shoujo&quot; Movie                               -0.176810
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.225632
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.074303
# &quot;Bungaku Shoujo&quot; Memoire                             0.071005
# &quot;Bungaku Shoujo&quot; Movie                               0.035272
# .hack//G.U. Returner                                           0.225632
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         -0.136677
# &quot;Bungaku Shoujo&quot; Memoire                                         -0.239784
# &quot;Bungaku Shoujo&quot; Movie                                           -0.267096
# .hack//G.U. Returner                                                        0.207223
# .hack//G.U. Trilogy                                                         0.181058
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    -0.064022
# &quot;Bungaku Shoujo&quot; Memoire                    -0.130967
# &quot;Bungaku Shoujo&quot; Movie                      -0.255708
# .hack//G.U. Returner                                   0.247240
# .hack//G.U. Trilogy                                    0.162248
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.056066
# &quot;Bungaku Shoujo&quot; Memoire                          -0.018206
# &quot;Bungaku Shoujo&quot; Movie                            -0.206954
# .hack//G.U. Returner                                         0.832848
# .hack//G.U. Trilogy                                          0.222114
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.100450
# &quot;Bungaku Shoujo&quot; Memoire                          -0.140926
# &quot;Bungaku Shoujo&quot; Movie                            -0.263878
# .hack//G.U. Returner                                         0.392866
# .hack//G.U. Trilogy                                          0.080584
#
# name                                                .hack//Quantum    ...     \
# name                                                                  ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.038155    ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.011126    ...
# &quot;Bungaku Shoujo&quot; Movie                          0.015581    ...
# .hack//G.U. Returner                                      0.158088    ...
# .hack//G.U. Trilogy                                       0.083679    ...
#
# name                                                gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                        -0.009234
# &quot;Bungaku Shoujo&quot; Memoire                                                        -0.007050
# &quot;Bungaku Shoujo&quot; Movie                                                           0.084531
# .hack//G.U. Returner                                                                      -0.057279
# .hack//G.U. Trilogy                                                                       -0.060506
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...               -0.038737
# &quot;Bungaku Shoujo&quot; Memoire                               -0.006382
# &quot;Bungaku Shoujo&quot; Movie                                 -0.135897
# .hack//G.U. Returner                                              0.073108
# .hack//G.U. Trilogy                                               0.013142
#
# name                                                iDOLM@STER Xenoglossia Specials  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                        -0.006869
# &quot;Bungaku Shoujo&quot; Memoire                                        -0.011489
# &quot;Bungaku Shoujo&quot; Movie                                          -0.075895
# .hack//G.U. Returner                                                       0.059142
# .hack//G.U. Trilogy                                                        0.063381
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.019452  0.201674
# &quot;Bungaku Shoujo&quot; Memoire                 -0.050795 -0.092922
# &quot;Bungaku Shoujo&quot; Movie                    0.002266  0.076769
# .hack//G.U. Returner                                0.012618 -0.319545
# .hack//G.U. Trilogy                                 0.011210 -0.071299
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.183179
# &quot;Bungaku Shoujo&quot; Memoire                      0.058097
# &quot;Bungaku Shoujo&quot; Movie                        0.170040
# .hack//G.U. Returner                                   -0.399158
# .hack//G.U. Trilogy                                    -0.063988
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.314348
# &quot;Bungaku Shoujo&quot; Memoire                                                -0.125238
# &quot;Bungaku Shoujo&quot; Movie                                                   0.251650
# .hack//G.U. Returner                                                              -0.195558
# .hack//G.U. Trilogy                                                               -0.019761
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.266959
# &quot;Bungaku Shoujo&quot; Memoire                     -0.136172
# &quot;Bungaku Shoujo&quot; Movie                        0.264401
# .hack//G.U. Returner                                   -0.463388
# .hack//G.U. Trilogy                                    -0.029549
#
# name                                                xxxHOLiC Shunmuki  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.255924
# &quot;Bungaku Shoujo&quot; Memoire                          -0.149680
# &quot;Bungaku Shoujo&quot; Movie                             0.288801
# .hack//G.U. Returner                                        -0.560174
# .hack//G.U. Trilogy                                         -0.099989
#
# name                                                       ◯
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.030515
# &quot;Bungaku Shoujo&quot; Memoire                  0.023176
# &quot;Bungaku Shoujo&quot; Movie                   -0.100427
# .hack//G.U. Returner                                0.125831
# .hack//G.U. Trilogy                                 0.040984
#
# [5 rows x 6780 columns]

# %% [markdown]
# ### Item-Item Pearson Implementation

# %%
def items_Avg_Rating_Matrix(itemMatrix):
    avgItemsRating = {}
    for itemID in itemMatrix:
        ratingsSum = 0.0
        counter = 0
        for rating in itemMatrix[itemID]:
            if not np.isnan(rating):
                ratingsSum += rating
                counter += 1
            else:
                continue
        avgItemsRating[itemID] = ratingsSum / counter
    return avgItemsRating

def item_Avg_Rating(itemID):
    itemRatings = pivTrain.loc[itemID, :]
    avgItemRatingList = 0.0
    counter = 0
    for rating in itemRatings:
        if not np.isnan(rating):
            avgItemRatingList += rating
            counter += 1
        else:
            continue
    return avgItemRatingList/counter

# %%
avgItemRatings = items_Avg_Rating_Matrix(pivTrain)
# print avgItemRatings
# avgItemRating = item_Avg_Rating(3)
# print avgItemRating

# %%
def rating_Item_Pearson_Prediction(userID, animeName):
    if userID in pivTrainNorm.columns:
        allItemSimilarity = trainItemPSimData.sort_values(by=animeName, ascending=False).loc[:,animeName]
        itemAvg = avgItemRatings[animeName]
        ratingWeight = 0.0
        similarityWeight = 0.0
        topNUsers = 0
        
        for itemX in allItemSimilarity.index:
            if animeName == itemX:
                continue
            
            itemXRating = pivTrain.loc[userID, itemX]
            if itemXRating < 0.01:
                continue
    
            if topNUsers < 50:
                itemXAvg = avgItemRatings[itemX]
                itemXSimilarity = allItemSimilarity.loc[itemX]
                if np.isnan(itemXRating):
                    continue
                elif not np.isnan(itemXRating):
                    ratingWeight += (itemXRating - itemXAvg)*itemXSimilarity
                    similarityWeight += abs(itemXSimilarity)
                    topNUsers += 1

    else:
        return ("No data available for UserID: {}".format(userID))
    
    return itemAvg + (ratingWeight / similarityWeight)

# %%
itemPearsonPrediction = rating_Item_Pearson_Prediction(3, "Zombie-Loan")
print itemPearsonPrediction
# Out:
# 6.680345096714367

# %% [markdown]
# ### Evaluation of Item-Item Pearson Similarity using MAE and RMSE

# %%
# Mean Absolute Error and Root Mean Squared Error
import math
def calc_Pearson_Error():
    meanAbsErrorList = 0.0
    rootMSEList = 0.0
    count = 0
    for anime in pivTest.columns:
        if anime in pivTestNorm.index:
            itemInfo = pivTest.loc[:, anime]
            for userID in itemInfo.index:
                trueRating = itemInfo[userID]
                if np.isnan(trueRating):
                    continue
                predictedRating = rating_Item_Pearson_Prediction(userID, anime)
                meanAbsErrorList += abs(predictedRating - trueRating)
                rootMSEList += (predictedRating - trueRating)**2
                count += 1
    return meanAbsErrorList/count, math.sqrt(rootMSEList/count)

# %%
pearsonMAE, pearsonRMSE = calc_Pearson_Error()
print "MAE: {}".format(pearsonMAE)
print "RMSE: {}".format(pearsonRMSE)
