# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %%
anime = pd.read_csv('../anime-recommendations-database/anime.csv')
animeRating = pd.read_csv('../anime-recommendations-database/rating.csv')

# %% [markdown]
# ### Cleaning Data for Missing Values

# %%
#Checking which values are null
print anime.isnull().sum()
print animeRating.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
anime['genre'] = anime['genre'].fillna('None')
anime['type'] = anime['type'].fillna('None')
anime['rating'] = anime['rating'].fillna('None')
anime.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
animeRating = animeRating[animeRating.rating > 0]
animeRating.rating.unique()
# Out:
# array([10,  8,  6,  9,  7,  3,  5,  4,  1,  2], dtype=int64)

# %%
fullMergedAnime = animeRating.merge(anime, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])
fullMergedAnime.head()
# Out:
#    user_id  anime_id  rating_user                    name  \
# 0        1      8074           10  Highschool of the Dead
# 1        3      8074            6  Highschool of the Dead
# 2        5      8074            2  Highschool of the Dead
# 3       12      8074            6  Highschool of the Dead
# 4       14      8074            6  Highschool of the Dead
#
#                                  genre type episodes rating  members
# 0  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 1  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 2  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 3  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892
# 4  Action, Ecchi, Horror, Supernatural   TV       12   7.46   535892

# %% [markdown]
# ### Splitting and Normalizing Data

# %%
trainData, testData = train_test_split(fullMergedAnime, test_size=0.2)

# %%
subTrainData = trainData[['user_id', 'anime_id', 'name', 'rating_user']]
#Limiting the dataframe
subTrainData = subTrainData[subTrainData.user_id <= 6000]

# %%
pivTrain = subTrainData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(pivTrain.shape)
pivTrain.head()
# Out:
# (5598, 6796)
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 2                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum ...  gdgd Fairies 2  \
# user_id                                    ...
# 1                      NaN             NaN ...             NaN
# 2                      NaN             NaN ...             NaN
# 3                      NaN             NaN ...             NaN
# 5                      NaN             NaN ...             NaN
# 7                      NaN             NaN ...             NaN
#
# name     iDOLM@STER Xenoglossia  iDOLM@STER Xenoglossia Specials  s.CRY.ed  \
# user_id
# 1                           NaN                              NaN       NaN
# 2                           NaN                              NaN       NaN
# 3                           NaN                              NaN       NaN
# 5                           NaN                              NaN       NaN
# 7                           NaN                              NaN       NaN
#
# name     xxxHOLiC  xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# user_id
# 1             NaN           NaN                                      NaN
# 2             NaN           NaN                                      NaN
# 3             NaN           NaN                                      NaN
# 5             2.0           NaN                                      NaN
# 7             NaN           NaN                                      NaN
#
# name     xxxHOLiC Rou  xxxHOLiC Shunmuki   ◯
# user_id
# 1                 NaN                NaN NaN
# 2                 NaN                NaN NaN
# 3                 NaN                NaN NaN
# 5                 NaN                NaN NaN
# 7                 NaN                NaN NaN
#
# [5 rows x 6796 columns]

# %%
subTestData = testData[['user_id', 'anime_id', 'name', 'rating_user']]
#Limiting the dataframe
subTestData = subTestData[subTestData.user_id <= 6000]

# %%
pivTest = subTestData.pivot_table(index=['user_id'], columns=['name'], values='rating_user')
print(pivTest.shape)
pivTest.head()
# Out:
# (5086, 5150)
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
# 8                                       NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                         NaN                  NaN
# 3                         NaN                  NaN
# 5                         NaN                  NaN
# 7                         NaN                  NaN
# 8                         NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# 7                                     NaN          NaN                NaN
# 8                                     NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum        ...          \
# user_id                                           ...
# 1                      NaN             NaN        ...
# 3                      NaN             NaN        ...
# 5                      NaN             NaN        ...
# 7                      NaN             NaN        ...
# 8                      NaN             NaN        ...
#
# name     ef: A Tale of Memories. - Recollections  gdgd Fairies 2  \
# user_id
# 1                                            NaN             NaN
# 3                                            NaN             NaN
# 5                                            NaN             NaN
# 7                                            NaN             NaN
# 8                                            NaN             NaN
#
# name     gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# user_id
# 1                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
#
# name     iDOLM@STER Xenoglossia  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# user_id
# 1                           NaN       NaN       NaN           NaN
# 3                           NaN       NaN       NaN           NaN
# 5                           NaN       NaN       NaN           NaN
# 7                           NaN       NaN       NaN           NaN
# 8                           NaN       NaN       NaN           NaN
#
# name     xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 1                                            NaN           NaN
# 3                                            NaN           NaN
# 5                                            NaN           NaN
# 7                                            NaN           NaN
# 8                                            NaN           NaN
#
# name     xxxHOLiC Shunmuki
# user_id
# 1                      NaN
# 3                      NaN
# 5                      NaN
# 7                      NaN
# 8                      NaN
#
# [5 rows x 5150 columns]

# %%
def create_Normalized_Matrix(piv):
    piv = piv.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)
    piv.fillna(0, inplace=True)
    piv = piv.T
    piv = piv.loc[:, (piv != 0).any(axis=0)]
    return piv

# %%
pivTrainNorm = create_Normalized_Matrix(pivTrain)
print (pivTrainNorm.shape)
# Out:
# (6796, 5129)

# %%
pivTestNorm = create_Normalized_Matrix(pivTest)
print (pivTestNorm.shape)
# Out:
# (5150, 4365)

# %% [markdown]
# ### Create Sparse Matrices

# %%
def create_Sparse_Matrix(userAnimeMatrix):
    return sp.sparse.csr_matrix(userAnimeMatrix.values)

# %%
pivTrainSparse = create_Sparse_Matrix(pivTrainNorm)

# %% [markdown]
# ### Item-Item Cosine Similarity

# %%
def item_Cosine_Similarity(itemMatrix):
    return cosine_similarity(itemMatrix)

def item_Similarity_DataFrame(itemSim, pivNorm):
    return pd.DataFrame(itemSim, index = pivNorm.index, columns = pivNorm.index)

# %%
itemCosineSim = item_Cosine_Similarity(pivTrainSparse)
trainItemSimData = item_Similarity_DataFrame(itemCosineSim, pivTrainNorm)
trainItemSimData.head()
# df_wc.loc[df_wc['nation']=='Germany', :]
# trainItemSimData.sort_values(by="1000-nen Joou: Queen Millennia", ascending=False)
# print pivTrainNorm.index
if "Zombie-Loan" in pivTrainNorm.index:
    print trainItemSimData.loc[:, "Zombie-Loan"]
# Out:
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi      -0.016634
# &quot;Bungaku Shoujo&quot; Memoire                        0.018036
# &quot;Bungaku Shoujo&quot; Movie                          0.002700
# .hack//G.U. Returner                                     -0.001762
# .hack//G.U. Trilogy                                      -0.022605
# .hack//G.U. Trilogy: Parody Mode                         -0.080269
# .hack//Gift                                               0.002190
# .hack//Intermezzo                                         0.014187
# .hack//Liminality                                         0.000438
# .hack//Quantum                                            0.016871
# .hack//Quantum: Sore ike! Bokura no Chimuchimu-chan!!     0.018936
# .hack//Roots                                              0.033806
# .hack//Sign                                               0.020084
# .hack//Tasogare no Udewa Densetsu                         0.049190
# .hack//Tasogare no Udewa Densetsu: Offline de Aimashou    0.011723
# .hack//The Movie: Sekai no Mukou ni                      -0.031958
# .hack//Unison                                             0.064096
# .hack//Versus: The Thanatos Report                        0.041941
# 009 Re:Cyborg                                             0.031855
# 009-1                                                     0.025981
# 009-1: R&amp;B                                           -0.010703
# 00:08                                                     0.000000
# 07-Ghost                                                  0.036766
# 1+2=Paradise                                             -0.013541
# 100-man-nen Chikyuu no Tabi: Bander Book                  0.000000
# 1001 Nights                                              -0.009284
# 11-nin Iru!                                              -0.030717
# 11eyes                                                    0.060951
# 11eyes Picture Drama                                      0.000000
# 11eyes: Momoiro Genmutan                                  0.036681
#                                                             ...
# Zoku Sayonara Zetsubou Sensei                            -0.023151
# Zombie-Loan                                               1.000000
# Zombie-Loan Specials                                      0.384171
# Zone of the Enders: Dolores, I                            0.008712
# Zone of the Enders: Idolo                                 0.000000
# Zonmi-chan: Meat Pie of the Dead                          0.022554
# Zukkoke Knight: Don De La Mancha                          0.000000
# Zutto Mae kara Suki deshita.: Kokuhaku Jikkou Iinkai     -0.021045
# _Summer                                                   0.027286
# _Summer Specials                                          0.000000
# eX-Driver                                                -0.003298
# eX-Driver the Movie                                       0.008576
# eX-Driver: Nina &amp; Rei Danger Zone                    -0.001651
# ef: A Tale of Melodies.                                   0.003448
# ef: A Tale of Melodies. - Prologue                        0.006190
# ef: A Tale of Memories.                                  -0.023770
# ef: A Tale of Memories. - Prologue                       -0.019285
# ef: A Tale of Memories. - Recollections                  -0.002879
# fake!fake!                                                0.000000
# gdgd Fairies                                             -0.008284
# gdgd Fairies 2                                            0.002252
# iDOLM@STER Xenoglossia                                    0.000777
# iDOLM@STER Xenoglossia Specials                          -0.007876
# s.CRY.ed                                                  0.019705
# xxxHOLiC                                                 -0.029910
# xxxHOLiC Kei                                             -0.008184
# xxxHOLiC Movie: Manatsu no Yoru no Yume                  -0.017438
# xxxHOLiC Rou                                             -0.057826
# xxxHOLiC Shunmuki                                         0.000529
# ◯                                                         0.000000
# Name: Zombie-Loan, Length: 6796, dtype: float64

# %% [markdown]
# ### Item-Item Cosine Implementation

# %%
def items_Avg_Rating_Matrix(itemMatrix):
    avgItemsRating = {}
    for itemID in itemMatrix:
        ratingsSum = 0.0
        counter = 0
        for rating in itemMatrix[itemID]:
            if not np.isnan(rating):
                ratingsSum += rating
                counter += 1
            else:
                continue
        avgItemsRating[itemID] = ratingsSum / counter
    return avgItemsRating

def item_Avg_Rating(itemID):
    itemRatings = pivTrain.loc[itemID, :]
    avgItemRatingList = 0.0
    counter = 0
    for rating in itemRatings:
        if not np.isnan(rating):
            avgItemRatingList += rating
            counter += 1
        else:
            continue
    return avgItemRatingList/counter

# %%
avgItemRatings = items_Avg_Rating_Matrix(pivTrain)
avgTestItemRatings = items_Avg_Rating_Matrix(pivTest)
# print avgItemRatings
# avgItemRating = item_Avg_Rating(3)
# print avgItemRating

# %%
def rating_Item_Cosine_Prediction(userID, animeName):
    if animeName in avgItemRatings:
        itemAvg = avgItemRatings[animeName]
    else:
        itemAvg = avgTestItemRatings[animeName]
        
    if animeName in pivTrainNorm.index and userID in pivTrainNorm.columns:
        allItemSimilarity = trainItemSimData.sort_values(by=animeName, ascending=False).loc[:,animeName]
        ratingWeight = 0.0
        similarityWeight = 0.0
        topNUsers = 0
        
        for itemX in allItemSimilarity.index:
            if animeName == itemX:
                continue
            
            itemXRating = pivTrain.loc[userID, itemX]
            if itemXRating < 0.01:
                continue
    
            if topNUsers < 50:
                itemXAvg = avgItemRatings[itemX]
                itemXSimilarity = allItemSimilarity.loc[itemX]
                if np.isnan(itemXRating):
                    continue
                elif not np.isnan(itemXRating):
                    ratingWeight += (itemXRating - itemXAvg)*itemXSimilarity
                    similarityWeight += abs(itemXSimilarity)
                    topNUsers += 1
    else:
        return itemAvg
    
    if similarityWeight > 0:
        return itemAvg + (ratingWeight / similarityWeight)
    else:
        return itemAvg

# %%
itemCosinePrediction = rating_Item_Cosine_Prediction(3, "Zombie-Loan")
print itemCosinePrediction
# Out:
# 6.748133946140575

# %% [markdown]
# ### Evaluation of Item-Item Cosine Similarity using MAE and RMSE

# %%
# Mean Absolute Error and Root Mean Squared Error
import math
def calc_Cosine_Error():
    meanAbsErrorList = 0.0
    rootMSEList = 0.0
    count = 0
    for anime in pivTest.columns:
        if anime in pivTestNorm.index:
            itemInfo = pivTest.loc[:, anime]
            for userID in itemInfo.index:
                trueRating = itemInfo[userID]
                if np.isnan(trueRating):
                    continue
                predictedRating = rating_Item_Cosine_Prediction(userID, anime)
                meanAbsErrorList += abs(predictedRating - trueRating)
                rootMSEList += (predictedRating - trueRating)**2
                count += 1
    return meanAbsErrorList/count, math.sqrt(rootMSEList/count)

# %%
cosineMAE, cosineRMSE = calc_Cosine_Error()
print "MAE: {}".format(cosineMAE)
print "RMSE: {}".format(cosineRMSE)
# Out:
# MAE: 0.869646313672
# RMSE: 1.1549518603

# %% [markdown]
# ### Item-Item Pearson Similarity

# %%
def pearson_Covariance(itemMatrix):
    return np.cov(itemMatrix)

def pearson_Similarity(itemCovariance):
    return np.corrcoef(itemCovariance)

# %%
itemPearsonCovariance = pearson_Covariance(pivTrainNorm.values)

# %%
itemPearsonSim = pearson_Similarity(itemPearsonCovariance)
# Out:
# C:\Users\kevin\Anaconda2\envs\cs670\lib\site-packages\numpy\lib\function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\kevin\Anaconda2\envs\cs670\lib\site-packages\numpy\lib\function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
trainItemPSimData = item_Similarity_DataFrame(itemPearsonSim, pivTrainNorm)
trainItemPSimData.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.089215
# &quot;Bungaku Shoujo&quot; Movie                                                             0.151401
# .hack//G.U. Returner                                                                        -0.072505
# .hack//G.U. Trilogy                                                                         -0.015024
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.089215
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.319340
# .hack//G.U. Returner                                                         -0.100505
# .hack//G.U. Trilogy                                                          -0.004210
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.151401
# &quot;Bungaku Shoujo&quot; Memoire                                          0.319340
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                       -0.245691
# .hack//G.U. Trilogy                                                        -0.148294
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             -0.072505
# &quot;Bungaku Shoujo&quot; Memoire                             -0.100505
# &quot;Bungaku Shoujo&quot; Movie                               -0.245691
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.592880
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...            -0.015024
# &quot;Bungaku Shoujo&quot; Memoire                            -0.004210
# &quot;Bungaku Shoujo&quot; Movie                              -0.148294
# .hack//G.U. Returner                                           0.592880
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                         -0.144006
# &quot;Bungaku Shoujo&quot; Memoire                                         -0.322874
# &quot;Bungaku Shoujo&quot; Movie                                           -0.317159
# .hack//G.U. Returner                                                        0.411574
# .hack//G.U. Trilogy                                                         0.362717
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    -0.053309
# &quot;Bungaku Shoujo&quot; Memoire                    -0.061399
# &quot;Bungaku Shoujo&quot; Movie                      -0.204142
# .hack//G.U. Returner                                   0.645326
# .hack//G.U. Trilogy                                    0.447771
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.016488
# &quot;Bungaku Shoujo&quot; Memoire                           0.037430
# &quot;Bungaku Shoujo&quot; Movie                            -0.159989
# .hack//G.U. Returner                                         0.627545
# .hack//G.U. Trilogy                                          0.475580
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          -0.107072
# &quot;Bungaku Shoujo&quot; Memoire                          -0.079327
# &quot;Bungaku Shoujo&quot; Movie                            -0.032996
# .hack//G.U. Returner                                         0.551149
# .hack//G.U. Trilogy                                          0.349264
#
# name                                                .hack//Quantum    ...     \
# name                                                                  ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.080694    ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.134922    ...
# &quot;Bungaku Shoujo&quot; Movie                          0.094942    ...
# .hack//G.U. Returner                                     -0.028338    ...
# .hack//G.U. Trilogy                                       0.040664    ...
#
# name                                                gdgd Fairies 2  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.004298
# &quot;Bungaku Shoujo&quot; Memoire                       -0.001993
# &quot;Bungaku Shoujo&quot; Movie                          0.019820
# .hack//G.U. Returner                                     -0.017738
# .hack//G.U. Trilogy                                      -0.031944
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...               -0.006761
# &quot;Bungaku Shoujo&quot; Memoire                                0.021003
# &quot;Bungaku Shoujo&quot; Movie                                 -0.076308
# .hack//G.U. Returner                                              0.090986
# .hack//G.U. Trilogy                                               0.067386
#
# name                                                iDOLM@STER Xenoglossia Specials  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                        -0.005966
# &quot;Bungaku Shoujo&quot; Memoire                                        -0.032716
# &quot;Bungaku Shoujo&quot; Movie                                          -0.069012
# .hack//G.U. Returner                                                       0.086478
# .hack//G.U. Trilogy                                                        0.077217
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats... -0.004126  0.133373
# &quot;Bungaku Shoujo&quot; Memoire                 -0.004766 -0.150453
# &quot;Bungaku Shoujo&quot; Movie                   -0.002330 -0.030397
# .hack//G.U. Returner                                0.056339 -0.215863
# .hack//G.U. Trilogy                                 0.039629 -0.227933
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.074438
# &quot;Bungaku Shoujo&quot; Memoire                     -0.023785
# &quot;Bungaku Shoujo&quot; Movie                        0.066061
# .hack//G.U. Returner                                   -0.290169
# .hack//G.U. Trilogy                                    -0.297508
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.279446
# &quot;Bungaku Shoujo&quot; Memoire                                                -0.233713
# &quot;Bungaku Shoujo&quot; Movie                                                   0.066502
# .hack//G.U. Returner                                                              -0.338123
# .hack//G.U. Trilogy                                                               -0.238288
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.225721
# &quot;Bungaku Shoujo&quot; Memoire                     -0.245689
# &quot;Bungaku Shoujo&quot; Movie                        0.066063
# .hack//G.U. Returner                                   -0.379819
# .hack//G.U. Trilogy                                    -0.300114
#
# name                                                xxxHOLiC Shunmuki  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.120732
# &quot;Bungaku Shoujo&quot; Memoire                          -0.238208
# &quot;Bungaku Shoujo&quot; Movie                             0.097960
# .hack//G.U. Returner                                        -0.271721
# .hack//G.U. Trilogy                                         -0.330100
#
# name                                                       ◯
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.072148
# &quot;Bungaku Shoujo&quot; Memoire                  0.048460
# &quot;Bungaku Shoujo&quot; Movie                   -0.090761
# .hack//G.U. Returner                                0.129778
# .hack//G.U. Trilogy                                 0.076963
#
# [5 rows x 6796 columns]

# %% [markdown]
# ### Item-Item Pearson Implementation

# %%
def items_Avg_Rating_Matrix(itemMatrix):
    avgItemsRating = {}
    for itemID in itemMatrix:
        ratingsSum = 0.0
        counter = 0
        for rating in itemMatrix[itemID]:
            if not np.isnan(rating):
                ratingsSum += rating
                counter += 1
            else:
                continue
        avgItemsRating[itemID] = ratingsSum / counter
    return avgItemsRating

def item_Avg_Rating(itemID):
    itemRatings = pivTrain.loc[itemID, :]
    avgItemRatingList = 0.0
    counter = 0
    for rating in itemRatings:
        if not np.isnan(rating):
            avgItemRatingList += rating
            counter += 1
        else:
            continue
    return avgItemRatingList/counter

# %%
avgItemRatings = items_Avg_Rating_Matrix(pivTrain)
avgTestItemRatings = items_Avg_Rating_Matrix(pivTest)
# print avgItemRatings
# avgItemRating = item_Avg_Rating(3)
# print avgItemRating

# %%
def rating_Item_Pearson_Prediction(userID, animeName):
    if animeName in avgItemRatings:
        itemAvg = avgItemRatings[animeName]
    else:
        itemAvg = avgTestItemRatings[animeName]
        
    if animeName in pivTrainNorm.index and userID in pivTrainNorm.columns:
        allItemSimilarity = trainItemPSimData.sort_values(by=animeName, ascending=False).loc[:,animeName]
        ratingWeight = 0.0
        similarityWeight = 0.0
        topNUsers = 0
        
        for itemX in allItemSimilarity.index:
            if animeName == itemX:
                continue
            
            itemXRating = pivTrain.loc[userID, itemX]
            if itemXRating < 0.01:
                continue
    
            if topNUsers < 50:
                itemXAvg = avgItemRatings[itemX]
                itemXSimilarity = allItemSimilarity.loc[itemX]
                if np.isnan(itemXRating):
                    continue
                elif not np.isnan(itemXRating):
                    ratingWeight += (itemXRating - itemXAvg)*itemXSimilarity
                    similarityWeight += abs(itemXSimilarity)
                    topNUsers += 1
    else:
        return itemAvg
    
    if similarityWeight > 0:
        return itemAvg + (ratingWeight / similarityWeight)
    else:
        return itemAvg

# %%
itemPearsonPrediction = rating_Item_Pearson_Prediction(3, "Zombie-Loan")
print itemPearsonPrediction
# Out:
# 6.5980589845791995

# %% [markdown]
# ### Evaluation of Item-Item Pearson Similarity using MAE and RMSE

# %%
# Mean Absolute Error and Root Mean Squared Error
import math
def calc_Pearson_Error():
    meanAbsErrorList = 0.0
    rootMSEList = 0.0
    count = 0
    for anime in pivTest.columns:
        if anime in pivTestNorm.index:
            itemInfo = pivTest.loc[:, anime]
            for userID in itemInfo.index:
                trueRating = itemInfo[userID]
                if np.isnan(trueRating):
                    continue
                predictedRating = rating_Item_Pearson_Prediction(userID, anime)
                meanAbsErrorList += abs(predictedRating - trueRating)
                rootMSEList += (predictedRating - trueRating)**2
                count += 1
    return meanAbsErrorList/count, math.sqrt(rootMSEList/count)

# %%
pearsonMAE, pearsonRMSE = calc_Pearson_Error()
print "MAE: {}".format(pearsonMAE)
print "RMSE: {}".format(pearsonRMSE)
# Out:
# MAE: 0.8654
# RMSE: 1.153
